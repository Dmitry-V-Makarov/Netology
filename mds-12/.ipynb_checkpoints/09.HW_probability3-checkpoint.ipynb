# %% [markdown]
# ## Задание 9

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
# %matplotlib inline

# %% [markdown]
# Создайте случайную величину из любого выбранного вами распределения, для разных значений n сгенерируйте 1000 выборок размера n и постройте гистрограммы средних этих выборок.

# %%
rv = stats.norm(loc=1, scale=1)
sample = rv.rvs(size=1000)

# %%
x = np.linspace(-2,4,100)
pdf = rv.pdf(x)
plt.hist(sample, density=True, bins=30, label='sample histogram')
plt.plot(x, pdf, label='theoretical pdf', alpha=0.8)
plt.legend()
plt.ylabel('fraction of samples, $f(x)$')
plt.xlabel('$x$')
plt.show()

# %%
# Параметры запуска: размеры выборок и количество повторов генерации
n1 = np.random.randint(10, size=10)
n2 = np.random.randint(10, size=50)
n3 = np.random.randint(10, size=100)
n4 = np.random.randint(10, size=300)
n5 = np.random.randint(10, size=1000)

samples_count = 1000

# Массивы для сохранения средних по выборкам
a1 = np.array([])
a2 = np.array([])
a3 = np.array([])
a4 = np.array([])
a5 = np.array([])

for number in range(samples_count):
    # На каждом цикле генерируем выборки разных размеров
    sample1 = rv.rvs(size=n1)
    sample2 = rv.rvs(size=n2)
    sample3 = rv.rvs(size=n3)
    sample4 = rv.rvs(size=n4)
    sample5 = rv.rvs(size=n5)
    
    # Считаем среднее по каждой выборке и добавляем в массив средних
    a1 = np.append(a1, sample1.mean())
    a2 = np.append(a2, sample2.mean())
    a3 = np.append(a3, sample3.mean())
    a4 = np.append(a4, sample4.mean())
    a5 = np.append(a5, sample5.mean())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-a8e563e337c6> in <module>
#      18     # На каждом цикле генерируем выборки разных размеров
#      19     sample1 = rv.rvs(size=n1)
# ---> 20     sample2 = rv.rvs(size=n2)
#      21     sample3 = rv.rvs(size=n3)
#      22     sample4 = rv.rvs(size=n4)
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in rvs(self, size, random_state)
#     454         kwds = self.kwds.copy()
#     455         kwds.update({'size': size, 'random_state': random_state})
# --> 456         return self.dist.rvs(*self.args, **kwds)
#     457
#     458     def sf(self, x):
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in rvs(self, *args, **kwds)
#    1002             vals = self._rvs(*args)
#    1003         else:
# -> 1004             vals = self._rvs(*args, size=size, random_state=random_state)
#    1005
#    1006         vals = vals * scale + loc
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py in _rvs(self, size, random_state)
#     296     """
#     297     def _rvs(self, size=None, random_state=None):
# --> 298         return random_state.standard_normal(size)
#     299
#     300     def _pdf(self, x):
#
# mtrand.pyx in numpy.random.mtrand.RandomState.standard_normal()
#
# _common.pyx in numpy.random._common.cont()
#
# ValueError: maximum supported dimension for an ndarray is 32, found 50

# %%
# Строим графики
# Подписи для графиков
label_1 = 'sample of ' + str(n1) + ' histogram'
label_2 = 'sample of ' + str(n2) + ' histogram'
label_3 = 'sample of ' + str(n3) + ' histogram'
label_4 = 'sample of ' + str(n4) + ' histogram'
label_5 = 'sample of ' + str(n5) + ' histogram'

plt.hist(a1, density=True, label=label_1, alpha = 0.3)
plt.hist(a2, density=True, label=label_2, alpha = 0.3)
plt.hist(a3, density=True, label=label_3, alpha = 0.3)
plt.hist(a4, density=True, label=label_4, alpha = 0.3)
plt.hist(a5, density=True, label=label_5, alpha = 0.3)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# C:\Users\dmvma\Anaconda3\lib\site-packages\numpy\lib\histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# Text(0.5, 0, '$x$')
